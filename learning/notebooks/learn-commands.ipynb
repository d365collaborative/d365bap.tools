// %% [markdown]
// # Learn commands
//
// The d365bap.tools module  contains multiple cmdlets. Use this notebook to learn how to get to know them.
//
// If this is your first time using this module, take a look at the [Get Started](get-started.ipynb) notebook.
//
// # List the available commands
//
// To list the available commands, use the `Get-Command` cmdlet.

// %%
Get-Command -Module d365bap.tools
// Out:
// CommandType     Name                                               Version    Source
// -----------     ----                                               -------    ------
// Function        Add-UdeWindowsDefenderRules                        0.0.22     d365bap.tools
// Function        Clear-UdeCredentialCache                           0.0.22     d365bap.tools
// Function        Clear-UdeDbJitCache                                0.0.22     d365bap.tools
// Function        Clear-UdeOrphanedConfig                            0.0.22     d365bap.tools
// Function        Compare-BapEnvironmentD365App                      0.0.22     d365bap.tools
// Function        Compare-BapEnvironmentUser                         0.0.22     d365bap.tools
// Function        Compare-BapEnvironmentVirtualEntity                0.0.22     d365bap.tools
// Function        Confirm-BapEnvironmentIntegration                  0.0.22     d365bap.tools
// Function        Confirm-UdeVs2022Installation                      0.0.22     d365bap.tools
// Function        Export-BapEnvironmentSolution                      0.0.22     d365bap.tools
// Function        Get-BapEnvironment                                 0.0.22     d365bap.tools
// Function        Get-PpacApplicationUser                  0.0.22     d365bap.tools
// Function        Get-BapEnvironmentD365App                          0.0.22     d365bap.tools
// Function        Get-PpacD365PlatformUpdate                     0.0.22     d365bap.tools
// Function        Get-BapEnvironmentLinkEnterprisePolicy             0.0.22     d365bap.tools
// Function        Get-BapEnvironmentOperation                        0.0.22     d365bap.tools
// Function        Get-BapEnvironmentPowerApp                         0.0.22     d365bap.tools
// Function        Get-BapEnvironmentSecurityRole                     0.0.22     d365bap.tools
// Function        Get-BapEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Get-BapEnvironmentSolution                         0.0.22     d365bap.tools
// Function        Get-BapEnvironmentUser                             0.0.22     d365bap.tools
// Function        Get-BapEnvironmentVirtualEntity                    0.0.22     d365bap.tools
// Function        Get-BapTenant                                      0.0.22     d365bap.tools
// Function        Get-BapTenantDetail                                0.0.22     d365bap.tools
// Function        Get-FnOEnvironmentSecurityRole                     0.0.22     d365bap.tools
// Function        Get-FnOEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Get-FnOEnvironmentUser                             0.0.22     d365bap.tools
// Function        Get-UdeConfig                                      0.0.22     d365bap.tools
// Function        Get-UdeConnection                                  0.0.22     d365bap.tools
// Function        Get-UdeCredentialCache                             0.0.22     d365bap.tools
// Function        Get-UdeDbJit                                       0.0.22     d365bap.tools
// Function        Get-UdeDbJitCache                                  0.0.22     d365bap.tools
// Function        Get-UdeDeveloperFile                               0.0.22     d365bap.tools
// Function        Get-UdeEnvironment                                 0.0.22     d365bap.tools
// Function        Get-UdeEnvironmentModule                           0.0.22     d365bap.tools
// Function        Get-UdeEnvironmentOperationHistory                 0.0.22     d365bap.tools
// Function        Get-UdeEnvironmentPackage                          0.0.22     d365bap.tools
// Function        Get-UdeVsPackageDeploy                             0.0.22     d365bap.tools
// Function        Get-UdeVsPowerPlatformExtensionHistory             0.0.22     d365bap.tools
// Function        Get-UdeXrefDb                                      0.0.22     d365bap.tools
// Function        Invoke-PpacD365PlatformUpdate                  0.0.22     d365bap.tools
// Function        Invoke-BapEnvironmentInstallD365App                0.0.22     d365bap.tools
// Function        Invoke-BapInstallAzCopy                            0.0.22     d365bap.tools
// Function        Set-BapAzCopyPath                                  0.0.22     d365bap.tools
// Function        Set-BapEnvironmentAdminMode                        0.0.22     d365bap.tools
// Function        Set-BapEnvironmentLinkEnterprisePolicy             0.0.22     d365bap.tools
// Function        Set-BapEnvironmentSecurityGroup                    0.0.22     d365bap.tools
// Function        Set-BapEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Set-BapEnvironmentVirtualEntity                    0.0.22     d365bap.tools
// Function        Set-BapTenantDetail                                0.0.22     d365bap.tools
// Function        Set-FnOEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Set-UdeConfig                                      0.0.22     d365bap.tools
// Function        Set-UdeDbJitCache                                  0.0.22     d365bap.tools
// Function        Set-UdeEnvironmentInSession                        0.0.22     d365bap.tools
// Function        Start-UdeDatabaseRefresh                           0.0.22     d365bap.tools
// Function        Start-UdeDbSsms                                    0.0.22     d365bap.tools
// Function        Switch-BapTenant                                   0.0.22     d365bap.tools
// Function        Update-BapEnvironmentVirtualEntityMetadata         0.0.22     d365bap.tools

// %% [markdown]
// Since this is quite a long list, you can also filter the results. For example, to list only the commands that contain "Environment" in their name, run the following cell:

// %%
Get-Command -Module d365bap.tools -Noun *Environment*
// Out:
// CommandType     Name                                               Version    Source
// -----------     ----                                               -------    ------
// Function        Compare-BapEnvironmentD365App                      0.0.22     d365bap.tools
// Function        Compare-BapEnvironmentUser                         0.0.22     d365bap.tools
// Function        Compare-BapEnvironmentVirtualEntity                0.0.22     d365bap.tools
// Function        Confirm-BapEnvironmentIntegration                  0.0.22     d365bap.tools
// Function        Export-BapEnvironmentSolution                      0.0.22     d365bap.tools
// Function        Get-BapEnvironment                                 0.0.22     d365bap.tools
// Function        Get-PpacApplicationUser                  0.0.22     d365bap.tools
// Function        Get-BapEnvironmentD365App                          0.0.22     d365bap.tools
// Function        Get-PpacD365PlatformUpdate                     0.0.22     d365bap.tools
// Function        Get-BapEnvironmentLinkEnterprisePolicy             0.0.22     d365bap.tools
// Function        Get-BapEnvironmentOperation                        0.0.22     d365bap.tools
// Function        Get-BapEnvironmentPowerApp                         0.0.22     d365bap.tools
// Function        Get-BapEnvironmentSecurityRole                     0.0.22     d365bap.tools
// Function        Get-BapEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Get-BapEnvironmentSolution                         0.0.22     d365bap.tools
// Function        Get-BapEnvironmentUser                             0.0.22     d365bap.tools
// Function        Get-BapEnvironmentVirtualEntity                    0.0.22     d365bap.tools
// Function        Get-FnOEnvironmentSecurityRole                     0.0.22     d365bap.tools
// Function        Get-FnOEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Get-FnOEnvironmentUser                             0.0.22     d365bap.tools
// Function        Get-UdeEnvironment                                 0.0.22     d365bap.tools
// Function        Get-UdeEnvironmentModule                           0.0.22     d365bap.tools
// Function        Get-UdeEnvironmentOperationHistory                 0.0.22     d365bap.tools
// Function        Get-UdeEnvironmentPackage                          0.0.22     d365bap.tools
// Function        Invoke-PpacD365PlatformUpdate                  0.0.22     d365bap.tools
// Function        Invoke-BapEnvironmentInstallD365App                0.0.22     d365bap.tools
// Function        Set-BapEnvironmentAdminMode                        0.0.22     d365bap.tools
// Function        Set-BapEnvironmentLinkEnterprisePolicy             0.0.22     d365bap.tools
// Function        Set-BapEnvironmentSecurityGroup                    0.0.22     d365bap.tools
// Function        Set-BapEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Set-BapEnvironmentVirtualEntity                    0.0.22     d365bap.tools
// Function        Set-FnOEnvironmentSecurityRoleMember               0.0.22     d365bap.tools
// Function        Set-UdeEnvironmentInSession                        0.0.22     d365bap.tools
// Function        Update-BapEnvironmentVirtualEntityMetadata         0.0.22     d365bap.tools

// %% [markdown]
// # Learn more about a cmdlet
//
// The names of the cmdlets follow the conventions for using a [PowerShell verb](https://learn.microsoft.com/en-us/powershell/scripting/developer/cmdlet/approved-verbs-for-windows-powershell-commands) as the first part of the name. If you are familiar with that convention, you can already guess from the name alone a lot about the purpose of a cmdlet.
//
// To learn more about a cmdlet, you can use the `Get-Help` cmdlet, which was introduced in [Get Started](get-started.ipynb).

// %%
Get-Help Get-BapEnvironmentUser
// Out:
// NAME
//     Get-BapEnvironmentUser
//
// SYNOPSIS
//     Get users from environment
//
//
// SYNTAX
//     Get-BapEnvironmentUser [-EnvironmentId] <String> [-IncludeAppIds] [-AsExcelOutput]
//     [<CommonParameters>]
//
//
// DESCRIPTION
//     Enables the user to fetch all users from the environment
//
//     Utilizes the built-in "systemusers" OData entity
//
//     Allows the user to include all users, based on those who has the ApplicationId property filled
//
//
// RELATED LINKS
//
// REMARKS
//     To see the examples, type: "Get-Help Get-BapEnvironmentUser -Examples"
//     For more information, type: "Get-Help Get-BapEnvironmentUser -Detailed"
//     For technical information, type: "Get-Help Get-BapEnvironmentUser -Full"

// %% [markdown]
// # Authenticate
//
// Remember that in order to run a cmdlet, you must authenticate your Azure account first with `Connect-AzAccount`. Review [Get Started](get-started.ipynb) on how to do this. For the purpose of this notebook, the following cell is provided to do the authentication. Feel free to change it to suit your needs.

// %%
Connect-AzAccount -UseDeviceAuthentication
// Out:
// WARNING: To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code ABCD1234 to authenticate.
//
// Account                  SubscriptionName                 TenantId                             Envi
//                                                                                                ronm
//                                                                                                ent
// -------                  ----------------                 --------                             ----
// me@mycompany.com         MySubscriptionName               abcdefgh-1234-5678-90ab-cdefghijklmn Azu…

// %% [markdown]
// # The Get cmdlets
//
// The `Get` cmdlets are used to retrieve information about your business applications. They are often easy to use and provide interesting output, which makes them good candidates to explore first.
//
// ## Get-BapEnvironment and Get-BapEnvironmentUser
//
// In [Get Started](get-started.ipynb) you already learned about the `Get-BapEnvironment` cmdlet. The information from that can be used for other cmdlets. `Get-BapEnvironmentUser` requires an `-EnvironmentId` parameter to list the users of an environment. The following cell shows how the id of the first environment returned by `Get-BapEnvironment` is used with the `Get-BapEnvironmentUser` cmdlet to list the first 5 users.
//
// Remember that you can also use the `-AsExcelOutput` parameter instead to get the list of users as an Excel file.

// %%
$environments = Get-BapEnvironment
$firstEnvironmentId = $environments[0].EnvId
$environmentUsers = Get-BapEnvironmentUser -EnvironmentId $firstEnvironmentId
# Only list the first five users
$environmentUsers | Select-Object -First 5
// Out:
// Upn                            Name                           PpacAppId            PpacSystemUserId
// ---                            ----                           ---------            ----------------
//                                SYSTEM                                              abcdefgh-1234-5…
//                                INTEGRATION                                         abcdefgh-1234-5…
// 365Administrator@mycompany.com 365 Admin                                           abcdefgh-1234-5…
// crmoln@microsoft.com           Support User                                        abcdefgh-1234-5…
// crmoln2@microsoft.com          Delegated Admin                                     abcdefgh-1234-5…

// %% [markdown]
// ## Get-PpacApplicationUser
//
// In a similar fashion, you can use the `Get-PpacApplicationUser` cmdlet to list all the application users of an environment.

// %%
Get-PpacApplicationUser -EnvironmentId $firstEnvironmentId
// Out:
// PpacSystemUserId                     PpacAppName                    PpacAppId
// ----------------                     -----------                    ---------
// abcdefgh-1234-5678-90ab-cdefghijklmn Power Apps Checker Application abcdefgh-1234-5678-90ab-cdefg…

// %% [markdown]
// ## Get-BapEnvironmentD365App
//
// Moving on from users, the `Get-BapEnvironmentD365App` cmdlet lists all the solutions of an environment. This includes the solutions that make up the Dynamics 365 business applications.

// %%
Get-BapEnvironmentD365App -EnvironmentId $firstEnvironmentId
// Out:
// PpacD365AppName                PpacPackageName                InstalledVersion    UpdateAvailable S
//                                                                                                   t
//                                                                                                   a
//                                                                                                   t
//                                                                                                   u
//                                                                                                   s
// ---------------                ---------------                ----------------    --------------- -
// Agent Productivity Tools       AgentProductivityToolsAnchor   9.2.25104.1002      True            I
// appprofilemanager              msdyn_AppProfileManagerAnchor  10.1.25104.1011     True            I

// %% [markdown]
// ## Get-BapEnvironmentVirtualEntity
//
// The `Get-BapEnvironmentVirtualEntity` cmdlet lists all the virtual entities of an environment. Without any filters, this command can take a few minutes to complete. For demonstration purposes, the following cell uses a filter to only return virtual entities that contain the text "cust" in their name. But feel free to remove that filter or use your own filter expression.
//
// Note that this cmdlet requires a Dynamics 365 Finance and Operations app as part of the environment. You can filter the result of `Get-BapEnvironment` to only those that have a value for the `FnOEnvUri` property.

// %%
$fnoEnvironments = (Get-BapEnvironment | Where-Object { -not [string]::IsNullOrWhiteSpace($_.FnOEnvUri) })
Get-BapEnvironmentVirtualEntity -EnvironmentId $fnoEnvironments[0].EnvId -Name Cust*
// Out:
// EntityName                     IsVisible ChangeTrackingEnabled EntityGuid
// TaxCustomsTariffCodeEntity     False     False                 00005ea6-0000-0000-1207-005001000000
// TaxCustomsTariffCodeEntity     False     False                 00005ea6-0000-0000-1207-005001000000
// TaxCustomsTaxRegistrationNumb… False     False                 00005ea6-0000-0000-9202-005001000000
// TaxCustomsTaxRegistrationNumb… False     False                 00005ea6-0000-0000-9202-005001000000
// TaxServiceTaxRegistrationNumb… False     False                 00005ea6-0000-0000-913d-005001000000
// TaxServiceTaxRegistrationNumb… False     False                 00005ea6-0000-0000-913d-005001000000
// TNVEDToCustomsPaymentsRelatio… False     False                 00005ea6-0000-0000-0103-005001000000
// TNVEDToCustomsPaymentsRelatio… False     False                 00005ea6-0000-0000-0103-005001000000
// TrvAdminCustomFieldsEntity     False     False                 00005ea6-0000-0000-913e-005001000000
// TrvAdminCustomFieldsEntity     False     False                 00005ea6-0000-0000-913e-005001000000
// TrvExpMobileReportAdminCustom… False     False                 00005ea6-0000-0000-9f3e-005001000000
// TrvExpMobileReportAdminCustom… False     False                 00005ea6-0000-0000-9f3e-005001000000

// %% [markdown]
// # Compare cmdlets
//
// The `Compare` cmdlets are used to compare different aspects of your business applications. They are useful to understand the differences between environments, solutions, and other objects. Internally, they use the `Get` cmdlets to retrieve the information to compare.
//
// ## Compare-BapEnvironmentUser
//
// The `Compare-BapEnvironmentUser` cmdlet compares the users of two environments. It is useful to understand the differences between the users of a development and a production environment, for example. Usually, you run the cmdlet with the `-ShowDiffOnly` switch to get only the users that are different between the two environments.

// %%
Compare-BapEnvironmentUser -SourceEnvironmentId $environments[0].EnvId -DestinationEnvironmentId $environments[1].EnvId -ShowDiffOnly
// Out:
// Email                          Name                           PpacAppId            SourceId
// -----                          ----                           ---------            --------
// user1@mycompany.com            User First                                          abcdefgh-1234-…
// user2@mycompany.com            User Second                                         abcdefgh-1234-…

// %% [markdown]
// ## Compare-BapEnvironmentD365App
//
// The `Compare-BapEnvironmentD365App` cmdlet compares the solutions of two environments. It is useful to understand the differences between the solutions of a development and a production environment, for example. Again, you usually run the cmdlet with the `-ShowDiffOnly` switch to get only the solutions that are different between the two environments.

// %%
Compare-BapEnvironmentD365App -SourceEnvironmentId $environments[0].EnvId -DestinationEnvironmentId $environments[1].EnvId -ShowDiffOnly
// Out:
// PpacD365AppName                      PpacPackageName                SourceVersion       Destination
//                                                                                         Version
// ---------------                      ---------------                -------------       -----------
// Agent Productivity Tools             AgentProductivityToolsAnchor   9.2.25104.1002      Missing
// appprofilemanager                    msdyn_AppProfileManagerAnchor  10.1.25104.1011     Missing
// Business Copilot AI                  msdyn_BusinessCopilotAIAnchor  2.0.0.1267          2.0.0.1351

// %% [markdown]
// # Other cmdlets
//
// The `Get` and `Compare` cmdlets are just a few of the cmdlets available in the module. In later, more scenario-specific notebooks, you will learn more about other cmdlets. But for now, you can use the `Get-Command` and `Get-Help` cmdlets to learn about them. Feel free to use the following cell for your own experiments.

// %%
# How about listing all the environments that have a specific D365 app installed?
